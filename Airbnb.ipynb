# %%
import pandas as pd

# %%
df = pd.read_csv('listings.csv')

# %%
df.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2539  https://www.airbnb.com/rooms/2539  20260614073253   2026-06-15
# 1  6848  https://www.airbnb.com/rooms/6848  20260614073253   2026-06-14
# 2  6872  https://www.airbnb.com/rooms/6872  20260614073253   2026-06-14
# 3  6990  https://www.airbnb.com/rooms/6990  20260614073253   2026-06-14
# 4  7097  https://www.airbnb.com/rooms/7097  20260614073253   2026-06-14
#
#         source                                               name  \
# 0  city scrape    11 Min to Manhattan • Prospect Park • Fast WiFi
# 1  city scrape                   Only 2 stops to Manhattan studio
# 2  city scrape  Uptown Sanctuary w/ Private Bath (Month to Month)
# 3  city scrape                            UES Beautiful Blue Room
# 4  city scrape      Perfect for Your Parents, With Garden & Patio
#
#                                          description  neighborhood_overview  \
# ...

# %%
df.describe()
# Out:
#                  id     scrape_id  neighborhood_overview       host_id  \
# count  3.025900e+04  3.025900e+04                    0.0  3.025900e+04
# mean   6.172513e+17  2.026061e+13                    NaN  2.672815e+15
# std    6.155147e+17  8.855615e+00                    NaN  6.705743e+16
# min    2.539000e+03  2.026061e+13                    NaN  1.678000e+03
# 25%    3.038760e+07  2.026061e+13                    NaN  2.069159e+07
# 50%    6.608782e+17  2.026061e+13                    NaN  1.074344e+08
# 75%    1.160901e+18  2.026061e+13                    NaN  3.948700e+08
# max    1.707075e+18  2.026061e+13                    NaN  1.704453e+18
#
#        host_profile_id  host_since  hosts_time_as_user_years  \
# count     2.991000e+04         0.0              29910.000000
# mean      1.469574e+18         NaN                  8.284754
# std       2.417060e+16         NaN                  3.934796
# min       1.462506e+18         NaN                  0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30259 entries, 0 to 30258
# Data columns (total 90 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            30259 non-null  int64
#  1   listing_url                                   30259 non-null  object
#  2   scrape_id                                     30259 non-null  int64
#  3   last_scraped                                  30259 non-null  object
#  4   source                                        30259 non-null  object
#  5   name                                          30258 non-null  object
#  6   description                                   29357 non-null  object
#  7   neighborhood_overview                         0 non-null      float64
#  8   picture_url                                   30259 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_profile_id', 'host_profile_url', 'host_name',
#        'host_since', 'hosts_time_as_user_years', 'hosts_time_as_user_months',
#        'hosts_time_as_host_years', 'hosts_time_as_host_months',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
# ...

# %%
columns_to_drop = [
    'id', 'listing_url', 'scrape_id', 'last_scraped', 'source','calculated_host_listings_count',
       'calculated_host_listings_count_entire_homes',
       'calculated_host_listings_count_private_rooms',
       'calculated_host_listings_count_shared_rooms','license','minimum_minimum_nights', 'maximum_minimum_nights',
       'minimum_maximum_nights', 'maximum_maximum_nights',
       'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm','availability_30', 'availability_60',
       'availability_90', 'availability_365', 'calendar_last_scraped','number_of_reviews_ltm', 'number_of_reviews_l30d',
       'availability_eoy', 'number_of_reviews_ly', 'estimated_occupancy_l365d',
       'estimated_revenue_l365d','host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
       'host_listings_count', 'host_total_listings_count','host_url', 'host_profile_id', 'host_profile_url', 'host_name',

]

df.drop(columns=columns_to_drop,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30259 entries, 0 to 30258
# Data columns (total 54 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          30258 non-null  object
#  1   description                   29357 non-null  object
#  2   neighborhood_overview         0 non-null      float64
#  3   picture_url                   30259 non-null  object
#  4   host_id                       30259 non-null  int64
#  5   host_since                    0 non-null      float64
#  6   hosts_time_as_user_years      29910 non-null  float64
#  7   hosts_time_as_user_months     29910 non-null  float64
#  8   hosts_time_as_host_years      29910 non-null  float64
#  9   hosts_time_as_host_months     29910 non-null  float64
#  10  host_location                 23097 non-null  object
#  11  host_about                    17849 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['name', 'description', 'neighborhood_overview', 'picture_url',
#        'host_id', 'host_since', 'hosts_time_as_user_years',
#        'hosts_time_as_user_months', 'hosts_time_as_host_years',
#        'hosts_time_as_host_months', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_verifications', 'host_has_profile_pic',
#        'host_identity_verified', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'price_quote_checkin_date', 'price_quote_checkout_date',
#        'price_quote_total_price', 'price_quote_price_per_night',
#        'price_quote_raw', 'minimum_nights', 'maximum_nights',
#        'calendar_updated', 'has_availability', 'number_of_reviews',
# ...

# %%
columns_to_drop =  [
    'hosts_time_as_user_months', 'hosts_time_as_host_years',
       'hosts_time_as_host_months', 'host_location', 'host_about',
       'host_response_time', 'host_response_rate', 'host_acceptance_rate',
       'host_is_superhost','bathrooms_text','price_quote_checkin_date', 'price_quote_checkout_date',
       'price_quote_total_price', 'price_quote_price_per_night',
       'price_quote_raw', 'calendar_updated','first_review','last_review','review_scores_value','reviews_per_month',
]
df.drop(columns=columns_to_drop,inplace=True)

# %%
df.columns
# Out:
# Index(['name', 'description', 'neighborhood_overview', 'picture_url',
#        'host_id', 'host_since', 'hosts_time_as_user_years',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'amenities', 'price', 'minimum_nights', 'maximum_nights',
#        'has_availability', 'number_of_reviews', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'instant_bookable'],
#       dtype='object')

# %%
df[['neighbourhood_cleansed','neighbourhood','neighbourhood_group_cleansed']]
# Out:
#       neighbourhood_cleansed  neighbourhood neighbourhood_group_cleansed
# 0                 Kensington            NaN                     Brooklyn
# 1               Williamsburg            NaN                     Brooklyn
# 2                East Harlem            NaN                    Manhattan
# 3                East Harlem            NaN                    Manhattan
# 4                Fort Greene            NaN                     Brooklyn
# ...                      ...            ...                          ...
# 30254        Upper East Side            NaN                    Manhattan
# 30255            South Slope            NaN                     Brooklyn
# 30256                 Harlem            NaN                    Manhattan
# 30257       Long Island City            NaN                       Queens
# 30258        Jackson Heights            NaN                       Queens
#
# [30259 rows x 3 columns]

# %%
columns_to_drop = ['name', 'description','picture_url','host_id', 'host_since', 'hosts_time_as_user_years','neighbourhood_cleansed','neighbourhood','neighbourhood_group_cleansed']
df.drop(columns=columns_to_drop,inplace=True)

# %%
df.describe()
# Out:
#        neighborhood_overview  host_verifications      latitude     longitude  \
# count                    0.0                 0.0  30259.000000  30259.000000
# mean                     NaN                 NaN     40.728580    -73.946481
# std                      NaN                 NaN      0.056459      0.057369
# min                      NaN                 NaN     40.504560    -74.251907
# 25%                      NaN                 NaN     40.687550    -73.984115
# 50%                      NaN                 NaN     40.728240    -73.955490
# 75%                      NaN                 NaN     40.762050    -73.926770
# max                      NaN                 NaN     40.912017    -73.711822
#
#        accommodates     bathrooms      bedrooms          beds  minimum_nights  \
# count  30259.000000  20147.000000  19286.000000  20839.000000    30257.000000
# mean       2.862785      1.212612      1.573473      1.716685       26.893611
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30259 entries, 0 to 30258
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   neighborhood_overview        0 non-null      float64
#  1   host_verifications           0 non-null      float64
#  2   host_has_profile_pic         29910 non-null  object
#  3   host_identity_verified       29910 non-null  object
#  4   latitude                     30259 non-null  float64
#  5   longitude                    30259 non-null  float64
#  6   property_type                30259 non-null  object
#  7   room_type                    30259 non-null  object
#  8   accommodates                 30259 non-null  int64
#  9   bathrooms                    20147 non-null  float64
#  10  bedrooms                     19286 non-null  float64
#  11  beds                         20839 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['neighborhood_overview', 'host_verifications', 'host_has_profile_pic',
#        'host_identity_verified', 'latitude', 'longitude', 'property_type',
#        'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds',
#        'amenities', 'price', 'minimum_nights', 'maximum_nights',
#        'has_availability', 'number_of_reviews', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'instant_bookable'],
#       dtype='object')

# %%
df[['review_scores_accuracy', 'review_scores_cleanliness',
       'review_scores_checkin', 'review_scores_communication',
       'review_scores_location', 'instant_bookable']]
# Out:
#        review_scores_accuracy  review_scores_cleanliness  \
# 0                        4.67                       4.90
# 1                        4.60                       4.85
# 2                        5.00                       5.00
# 3                        4.83                       4.95
# 4                        4.91                       4.89
# ...                       ...                        ...
# 30254                     NaN                        NaN
# 30255                     NaN                        NaN
# 30256                     NaN                        NaN
# 30257                     NaN                        NaN
# 30258                     NaN                        NaN
#
#        review_scores_checkin  review_scores_communication  \
# 0                       4.89                         5.00
# 1                       4.85                         4.80
# 2                       5.00                         5.00
# ...

# %%
df[['instant_bookable']].isna().value_counts().sum()
# Out:
# np.int64(30259)

# %%
df.drop('instant_bookable',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['neighborhood_overview', 'host_verifications', 'host_has_profile_pic',
#        'host_identity_verified', 'latitude', 'longitude', 'property_type',
#        'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds',
#        'amenities', 'price', 'minimum_nights', 'maximum_nights',
#        'has_availability', 'number_of_reviews', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location'],
#       dtype='object')

# %%
df['neighborhood_overview']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 30254   NaN
# 30255   NaN
# 30256   NaN
# 30257   NaN
# 30258   NaN
# Name: neighborhood_overview, Length: 30259, dtype: float64

# %%
df.drop('neighborhood_overview',axis=1,inplace=True)

# %%
df.drop('host_has_profile_pic',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30259 entries, 0 to 30258
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   host_verifications           0 non-null      float64
#  1   host_identity_verified       29910 non-null  object
#  2   latitude                     30259 non-null  float64
#  3   longitude                    30259 non-null  float64
#  4   property_type                30259 non-null  object
#  5   room_type                    30259 non-null  object
#  6   accommodates                 30259 non-null  int64
#  7   bathrooms                    20147 non-null  float64
#  8   bedrooms                     19286 non-null  float64
#  9   beds                         20839 non-null  float64
#  10  amenities                    30259 non-null  object
#  11  price                        21515 non-null  object
# ...

# %%
df['host_identity_verified'].value_counts()
# Out:
# host_identity_verified
# t    28555
# f     1355
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

ls = LabelEncoder()
df['host_identity_verified'] = ls.fit_transform(df['host_identity_verified'])

# %%
df['host_identity_verified'].value_counts()
# Out:
# host_identity_verified
# 1    28555
# 0     1355
# 2      349
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30259 entries, 0 to 30258
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   host_verifications           0 non-null      float64
#  1   host_identity_verified       30259 non-null  int64
#  2   latitude                     30259 non-null  float64
#  3   longitude                    30259 non-null  float64
#  4   property_type                30259 non-null  object
#  5   room_type                    30259 non-null  object
#  6   accommodates                 30259 non-null  int64
#  7   bathrooms                    20147 non-null  float64
#  8   bedrooms                     19286 non-null  float64
#  9   beds                         20839 non-null  float64
#  10  amenities                    30259 non-null  object
#  11  price                        21515 non-null  object
# ...

# %%
df['property_type']
# Out:
# 0              Private room in condo
# 1                 Entire rental unit
# 2              Private room in condo
# 3        Private room in rental unit
# 4        Private room in guest suite
#                     ...
# 30254             Entire rental unit
# 30255                    Entire home
# 30256             Entire rental unit
# 30257             Entire rental unit
# 30258    Private room in rental unit
# Name: property_type, Length: 30259, dtype: object

# %%
print(df["property_type"].unique())
# Out:
# ['Private room in condo' 'Entire rental unit'
#  'Private room in rental unit' 'Private room in guest suite'
#  'Entire place' 'Entire condo' 'Private room in loft' 'Entire loft'
#  'Entire guest suite' 'Private room in townhouse' 'Entire home'
#  'Private room in home' 'Entire townhouse' 'Private room in houseboat'
#  'Private room in bed and breakfast' 'Entire guesthouse'
#  'Room in boutique hotel' 'Shared room in rental unit' 'Private room'
#  'Boat' 'Entire serviced apartment' 'Casa particular'
#  'Private room in villa' 'Private room in serviced apartment'
#  'Shared room in home' 'Shared room in townhouse' 'Cave'
#  'Private room in tiny home' 'Floor' 'Room in hotel'
#  'Shared room in condo' 'Private room in hostel' 'Entire bungalow'
#  'Houseboat' 'Room in aparthotel' 'Private room in guesthouse'
#  'Entire cottage' 'Room in serviced apartment' 'Private room in resort'
#  'Tiny home' 'Private room in tent' 'Entire villa' 'Entire vacation home'
# ...

# %%
df = pd.get_dummies(df, columns=["property_type"], dtype=int)

# %%
df.head()
# Out:
#    host_verifications  host_identity_verified   latitude  longitude  \
# 0                 NaN                       1  40.645937 -73.972164
# 1                 NaN                       1  40.709350 -73.953420
# 2                 NaN                       1  40.801070 -73.942550
# 3                 NaN                       1  40.787780 -73.947590
# 4                 NaN                       1  40.691940 -73.973890
#
#          room_type  accommodates  bathrooms  bedrooms  beds  \
# 0     Private room             2        1.0       1.0   2.0
# 1  Entire home/apt             3        1.0       2.0   1.0
# 2     Private room             1        1.0       NaN   1.0
# 3     Private room             1        1.0       NaN   1.0
# 4     Private room             2        1.0       NaN   2.0
#
#                                            amenities  ...  \
# 0  ["Bed linens", "Hot water", "Exterior security...  ...
# 1  ["Bed linens", "Hot water", "Fire extinguisher...  ...
# ...

# %%
df.drop('host_verifications',axis=1,inplace=True)

# %%
print(df["room_type"].unique())
# Out:
# ['Private room' 'Entire home/apt' 'Hotel room' 'Shared room']

# %%
df = pd.get_dummies(df, columns=["room_type"], dtype=int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30259 entries, 0 to 30258
# Data columns (total 92 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   host_identity_verified                            30259 non-null  int64
#  1   latitude                                          30259 non-null  float64
#  2   longitude                                         30259 non-null  float64
#  3   accommodates                                      30259 non-null  int64
#  4   bathrooms                                         20147 non-null  float64
#  5   bedrooms                                          19286 non-null  float64
#  6   beds                                              20839 non-null  float64
#  7   amenities                                         30259 non-null  object
#  8   price                                             21515 non-null  object
# ...

# %%
import ast
def count_amenities(x):
    if pd.isna(x):
      return 0
    try:
      return len(ast.literal_eval(x))
    except:
      return 0




df["amenities_count"] = df["amenities"].apply(count_amenities)

# %%
df["price"] = (
    df["price"]
    .str.replace("$", "", regex=False)
    .str.replace(",", "", regex=False)
)


df["price"] = pd.to_numeric(df["price"], errors="coerce")

# %%
df['price']
# Out:
# 0        113.97
# 1        117.27
# 2         80.06
# 3         77.17
# 4        202.47
#           ...
# 30254    232.77
# 30255    410.58
# 30256    184.00
# 30257    271.68
# 30258    119.47
# Name: price, Length: 30259, dtype: float64

# %%
df.isnull().sum()
# Out:
# host_identity_verified           0
# latitude                         0
# longitude                        0
# accommodates                     0
# bathrooms                    10112
#                              ...
# room_type_Entire home/apt        0
# room_type_Hotel room             0
# room_type_Private room           0
# room_type_Shared room            0
# amenities_count                  0
# Length: 93, dtype: int64

# %%
df['bathrooms']
# Out:
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
#         ...
# 30254    1.0
# 30255    2.0
# 30256    1.0
# 30257    1.0
# 30258    1.0
# Name: bathrooms, Length: 30259, dtype: float64

# %%
num_cols = df.select_dtypes(include=["int64", "float64"]).columns

df[num_cols] = df[num_cols].fillna(df[num_cols].median())

# %%
df.isnull().sum()
# Out:
# host_identity_verified       0
# latitude                     0
# longitude                    0
# accommodates                 0
# bathrooms                    0
#                             ..
# room_type_Entire home/apt    0
# room_type_Hotel room         0
# room_type_Private room       0
# room_type_Shared room        0
# amenities_count              0
# Length: 93, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30259 entries, 0 to 30258
# Data columns (total 93 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   host_identity_verified                            30259 non-null  int64
#  1   latitude                                          30259 non-null  float64
#  2   longitude                                         30259 non-null  float64
#  3   accommodates                                      30259 non-null  int64
#  4   bathrooms                                         30259 non-null  float64
#  5   bedrooms                                          30259 non-null  float64
#  6   beds                                              30259 non-null  float64
#  7   amenities                                         30259 non-null  object
#  8   price                                             30259 non-null  float64
# ...

# %%
df['amenities']
# Out:
# 0        ["Bed linens", "Hot water", "Exterior security...
# 1        ["Bed linens", "Hot water", "Fire extinguisher...
# 2        ["Dryer", "Exterior security cameras on proper...
# 3        ["Bed linens", "Hot water", "Fire extinguisher...
# 4        ["Bed linens", "Hot water", "Cleaning products...
#                                ...
# 30254    ["Bed linens", "Hot water", "Exterior security...
# 30255    ["Air conditioning", "Wifi", "Kitchen", "Smoke...
# 30256    ["Bed linens", "Hot water", "Exterior security...
# 30257    ["Exercise equipment", "Wifi", "Kitchen", "Smo...
# 30258    ["TV", "Exterior security cameras on property"...
# Name: amenities, Length: 30259, dtype: object

# %%
df.drop('amenities',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30259 entries, 0 to 30258
# Data columns (total 92 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   host_identity_verified                            30259 non-null  int64
#  1   latitude                                          30259 non-null  float64
#  2   longitude                                         30259 non-null  float64
#  3   accommodates                                      30259 non-null  int64
#  4   bathrooms                                         30259 non-null  float64
#  5   bedrooms                                          30259 non-null  float64
#  6   beds                                              30259 non-null  float64
#  7   price                                             30259 non-null  float64
#  8   minimum_nights                                    30259 non-null  float64
# ...

# %%
df['has_availability']
# Out:
# 0        t
# 1        t
# 2        t
# 3        t
# 4        t
#         ..
# 30254    t
# 30255    t
# 30256    t
# 30257    t
# 30258    t
# Name: has_availability, Length: 30259, dtype: object

# %%
cat_cols = df.select_dtypes(include=["object"]).columns
for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
df['has_availability']
# Out:
# 0        t
# 1        t
# 2        t
# 3        t
# 4        t
#         ..
# 30254    t
# 30255    t
# 30256    t
# 30257    t
# 30258    t
# Name: has_availability, Length: 30259, dtype: object

# %%
df['has_availability'] = ls.fit_transform(df['has_availability'])

# %%
df['has_availability']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 30254    1
# 30255    1
# 30256    1
# 30257    1
# 30258    1
# Name: has_availability, Length: 30259, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30259 entries, 0 to 30258
# Data columns (total 92 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   host_identity_verified                            30259 non-null  int64
#  1   latitude                                          30259 non-null  float64
#  2   longitude                                         30259 non-null  float64
#  3   accommodates                                      30259 non-null  int64
#  4   bathrooms                                         30259 non-null  float64
#  5   bedrooms                                          30259 non-null  float64
#  6   beds                                              30259 non-null  float64
#  7   price                                             30259 non-null  float64
#  8   minimum_nights                                    30259 non-null  float64
# ...

# %%
df.describe()
# Out:
#        host_identity_verified      latitude     longitude  accommodates  \
# count            30259.000000  30259.000000  30259.000000  30259.000000
# mean                 0.966754     40.728580    -73.946481      2.862785
# std                  0.234969      0.056459      0.057369      1.979306
# min                  0.000000     40.504560    -74.251907      1.000000
# 25%                  1.000000     40.687550    -73.984115      2.000000
# 50%                  1.000000     40.728240    -73.955490      2.000000
# 75%                  1.000000     40.762050    -73.926770      4.000000
# max                  2.000000     40.912017    -73.711822     16.000000
#
#           bathrooms      bedrooms          beds         price  minimum_nights  \
# count  30259.000000  30259.000000  30259.000000  30259.000000    30259.000000
# mean       1.141561      1.365511      1.493572    248.309509       26.893817
# std        0.453370      0.783561      1.091303    450.815085       27.476001
# ...

# %%
import matplotlib.pyplot as plt
df['price'].hist(bins=50)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,10))
sns.heatmap(df.corr(), cmap="coolwarm")
plt.show()

# %%
## Applying the log transformation to make the features symetrical beacuse the graph is right skewed now
import numpy as np

df["price"] = np.log1p(df["price"])

# %%
import matplotlib.pyplot as plt
df['price'].hist(bins=50)
plt.show()

# %%
corr = df.corr()

corr["price"].sort_values(ascending=False)
# Out:
# price                                        1.000000
# accommodates                                 0.479222
# beds                                         0.370251
# bedrooms                                     0.325280
# room_type_Entire home/apt                    0.301823
#                                                ...
# property_type_Private room in home          -0.204063
# minimum_nights                              -0.216901
# longitude                                   -0.249249
# property_type_Private room in rental unit   -0.319683
# room_type_Private room                      -0.335763
# Name: price, Length: 92, dtype: float64

# %%
corr = df.corr()["price"].sort_values()

print(corr)
# Out:
# room_type_Private room                      -0.335763
# property_type_Private room in rental unit   -0.319683
# longitude                                   -0.249249
# minimum_nights                              -0.216901
# property_type_Private room in home          -0.204063
#                                                ...
# room_type_Entire home/apt                    0.301823
# bedrooms                                     0.325280
# beds                                         0.370251
# accommodates                                 0.479222
# price                                        1.000000
# Name: price, Length: 92, dtype: float64

# %%
import matplotlib.pyplot as plt

df.boxplot(column="price")
plt.show()

# %%
corr = df.corr()["price"].sort_values()

corr.tail(15).plot(kind="barh", figsize=(8,6))
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30259 entries, 0 to 30258
# Data columns (total 92 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   host_identity_verified                            30259 non-null  int64
#  1   latitude                                          30259 non-null  float64
#  2   longitude                                         30259 non-null  float64
#  3   accommodates                                      30259 non-null  int64
#  4   bathrooms                                         30259 non-null  float64
#  5   bedrooms                                          30259 non-null  float64
#  6   beds                                              30259 non-null  float64
#  7   price                                             30259 non-null  float64
#  8   minimum_nights                                    30259 non-null  float64
# ...

# %%
import torch
import torch.nn as nn
from torch.optim import Adam
from torch.utils.data import Dataset,DataLoader
from torchsummary import summary
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import numpy as np

# %%
df['price']
# Out:
# 0        4.744671
# 1        4.772970
# 2        4.395190
# 3        4.358886
# 4        5.315519
#            ...
# 30254    5.454338
# 30255    6.020003
# 30256    5.220356
# 30257    5.608299
# 30258    4.791401
# Name: price, Length: 30259, dtype: float64

# %%
X = df.drop('price',axis=1)

# %%
y = df['price']

# %%
X
# Out:
#        host_identity_verified   latitude  longitude  accommodates  bathrooms  \
# 0                           1  40.645937 -73.972164             2        1.0
# 1                           1  40.709350 -73.953420             3        1.0
# 2                           1  40.801070 -73.942550             1        1.0
# 3                           1  40.787780 -73.947590             1        1.0
# 4                           1  40.691940 -73.973890             2        1.0
# ...                       ...        ...        ...           ...        ...
# 30254                       1  40.776070 -73.948900             3        1.0
# 30255                       1  40.664271 -73.984940             5        2.0
# 30256                       1  40.801140 -73.954090             4        1.0
# 30257                       1  40.739423 -73.961239             2        1.0
# 30258                       1  40.755661 -73.864949             3        1.0
#
# ...

# %%
y
# Out:
# 0        4.744671
# 1        4.772970
# 2        4.395190
# 3        4.358886
# 4        5.315519
#            ...
# 30254    5.454338
# 30255    6.020003
# 30256    5.220356
# 30257    5.608299
# 30258    4.791401
# Name: price, Length: 30259, dtype: float64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42,test_size=0.2)

# %%
X_test,X_val,y_test,y_val = train_test_split(X_test,y_test,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_val = scaler.transform(X_val)

# %%
## Making the custom Daaset
class dataset(Dataset):
  def __init__(self,X,y):
    self.X = torch.tensor(X,dtype=torch.float32)
    self.y = torch.tensor(y.to_numpy(),dtype=torch.float32)

  def __len__(self):
    return len(self.X)

  def __getitem__(self, index):
    return self.X[index],self.y[index]

# %%
training_data = dataset(X_train,y_train)
validation_data = dataset(X_val,y_val)

test_data = dataset(X_test,y_test)

# %%
train_dataloader = DataLoader(training_data,batch_size=8,shuffle=True)
validation_dataloader = DataLoader(validation_data,batch_size=8,shuffle=True)
test_dataloader = DataLoader(test_data,batch_size=8,shuffle=True)

# %%
import torch
import torch.nn as nn

# %%
import torch.nn as nn

class Model(nn.Module):
    def __init__(self, input_features):
        super().__init__()

        self.network = nn.Sequential(
            nn.Linear(input_features, 64),
            nn.ReLU(),

            nn.Linear(64, 32),
            nn.ReLU(),

            nn.Linear(32, 16),
            nn.ReLU(),

            nn.Linear(16, 1)
        )

    def forward(self, x):
        return self.network(x)

# %%
model = Model(input_features=X_train.shape[1])

# %%
summary(model,(X.shape[1],))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Linear-1                   [-1, 64]           5,888
#               ReLU-2                   [-1, 64]               0
#             Linear-3                   [-1, 32]           2,080
#               ReLU-4                   [-1, 32]               0
#             Linear-5                   [-1, 16]             528
#               ReLU-6                   [-1, 16]               0
#             Linear-7                    [-1, 1]              17
# ...
# Total params: 8,513
# Trainable params: 8,513
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.03
# Estimated Total Size (MB): 0.03
# ----------------------------------------------------------------

# %%
import torch.optim as optim
import torch.nn as nn

criterion = nn.MSELoss() ## Since continous probnlem

optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
train_losses = []
val_losses = []

epochs = 10

for epoch in range(epochs):

    model.train()
    train_loss = 0

    for inputs, labels in train_dataloader:

        predictions = model(inputs).squeeze()

        loss = criterion(predictions, labels)

        optimizer.zero_grad()

        loss.backward()

        optimizer.step()

        train_loss += loss.item()

    model.eval()

    val_loss = 0

    with torch.no_grad():

        for inputs, labels in validation_dataloader:

            predictions = model(inputs).squeeze()

            loss = criterion(predictions, labels)

            val_loss += loss.item()

    train_losses.append(train_loss / len(train_dataloader))
    val_losses.append(val_loss / len(validation_dataloader))

    print(
        f"Epoch [{epoch+1}/{epochs}] "
        f"Train Loss: {train_losses[-1]:.4f} "
        f"Val Loss: {val_losses[-1]:.4f}"
    )
# Out:
# Epoch [1/10] Train Loss: 0.7956 Val Loss: 0.2188
# Epoch [2/10] Train Loss: 0.2758 Val Loss: 0.2199
# Epoch [3/10] Train Loss: 0.2611 Val Loss: 0.2173
# Epoch [4/10] Train Loss: 0.2518 Val Loss: 0.2182
# Epoch [5/10] Train Loss: 0.2493 Val Loss: 0.2099
# Epoch [6/10] Train Loss: 0.2429 Val Loss: 0.1936
# Epoch [7/10] Train Loss: 0.2358 Val Loss: 0.1881
# Epoch [8/10] Train Loss: 0.2290 Val Loss: 0.1934
# Epoch [9/10] Train Loss: 0.2213 Val Loss: 0.1947
# Epoch [10/10] Train Loss: 0.2178 Val Loss: 0.1994

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

model.eval()

predictions = []
actuals = []

with torch.no_grad():
    for X_batch, y_batch in test_dataloader:
        outputs = model(X_batch)

        predictions.extend(outputs.cpu().numpy().flatten())
        actuals.extend(y_batch.cpu().numpy().flatten())

predictions = np.array(predictions)
actuals = np.array(actuals)

mae = mean_absolute_error(actuals, predictions)
rmse = np.sqrt(mean_squared_error(actuals, predictions))
r2 = r2_score(actuals, predictions)

print(f"MAE  : {mae:.4f}")
print(f"RMSE : {rmse:.4f}")
print(f"R²   : {r2:.4f}")
# Out:
# MAE  : 0.3502
# RMSE : 0.4729
# R²   : 0.5487

# %%
import numpy as np
import torch

# Select any sample from the test set
sample = X_test[0]   # Already scaled

model.eval()

with torch.no_grad():
    sample_tensor = torch.tensor(sample, dtype=torch.float32).unsqueeze(0)
    log_prediction = model(sample_tensor).item()

predicted_price = np.expm1(log_prediction)
actual_price = np.expm1(y_test.iloc[0]) if hasattr(y_test, "iloc") else np.expm1(y_test[0])

print(f"Predicted Price: ₹{predicted_price:.2f}")
print(f"Actual Price   : ₹{actual_price:.2f}")
# Out:
# Predicted Price: ₹188.72
# Actual Price   : ₹126.87
